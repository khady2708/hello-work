# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import missingno as msno

# %%
data_titanic = "./Datasets/data_titanic.csv"
data_energy_nat = "./Datasets/df_nat.csv"

# %% [markdown]
# # Titanic Dataset

# %% [markdown]
# ## Import data

# %%
df_titanic = pd.read_csv(data_titanic )
df_titanic.sample(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 549          550         1       2
# 8              9         1       3
# 632          633         1       1
# 48            49         0       3
# 473          474         1       2
# 820          821         1       1
# 590          591         0       3
# 482          483         0       3
# 736          737         0       3
# 555          556         0       1
# 353          354         0       3
# 527          528         0       1
# 114          115         0       3
# 151          152         1       1
# 757          758         0       2
# 613          614         0       3
# 343          344         0       2
# 252          253         0       1
# 308          309         0       2
# 723          724         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 549                     Davies, Master. John Morgan Jr    male   8.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 632                          Stahelin-Maeglin, Dr. Max    male  32.0      0
# 48                                 Samaan, Mr. Youssef    male   NaN      2
# 473       Jerwan, Mrs. Amin S (Marie Marthe Thuillard)  female  23.0      0
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 590                               Rintamaki, Mr. Matti    male  35.0      0
# 482                           Rouse, Mr. Richard Henry    male  50.0      0
# 736            Ford, Mrs. Edward (Margaret Ann Watson)  female  48.0      1
# 555                                 Wright, Mr. George    male  62.0      0
# 353                          Arnold-Franchi, Mr. Josef    male  25.0      1
# 527                                 Farthing, Mr. John    male   NaN      0
# 114                              Attalah, Miss. Malake  female  17.0      0
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 757                           Bailey, Mr. Percy Andrew    male  18.0      0
# 613                                   Horgan, Mr. John    male   NaN      0
# 343         Sedgwick, Mr. Charles Frederick Waddington    male  25.0      0
# 252                          Stead, Mr. William Thomas    male  62.0      0
# 308                                Abelson, Mr. Samuel    male  30.0      1
# 723                            Hodges, Mr. Henry Price    male  50.0      0
#
#      Parch             Ticket      Fare Cabin Embarked
# 549      1         C.A. 33112   36.7500   NaN        S
# 8        2             347742   11.1333   NaN        S
# 632      0              13214   30.5000   B50        C
# 48       0               2662   21.6792   NaN        C
# 473      0    SC/AH Basle 541   13.7917     D        C
# 820      1              12749   93.5000   B69        S
# 590      0  STON/O 2. 3101273    7.1250   NaN        S
# 482      0           A/5 3594    8.0500   NaN        S
# 736      3         W./C. 6608   34.3750   NaN        S
# 555      0             113807   26.5500   NaN        S
# 353      0             349237   17.8000   NaN        S
# 527      0           PC 17483  221.7792   C95        S
# 114      0               2627   14.4583   NaN        C
# 151      0             113776   66.6000    C2        S
# 757      0              29108   11.5000   NaN        S
# 613      0             370377    7.7500   NaN        Q
# 343      0             244361   13.0000   NaN        S
# 252      0             113514   26.5500   C87        S
# 308      0          P/PP 3381   24.0000   NaN        C
# 723      0             250643   13.0000   NaN        S

# %%
df_energy_nat = pd.read_csv(data_energy_nat)
df_energy_nat.sample(20)
# Out:
#                    DateTime  Consommation  Fioul  Charbon     Gaz  Nucléaire  \
# 18261   2012-07-09 05:15:00           NaN    NaN      NaN     NaN        NaN
# 39851   2013-02-19 02:45:00           NaN    NaN      NaN     NaN        NaN
# 60345   2013-09-20 14:15:00           NaN    NaN      NaN     NaN        NaN
# 44398   2013-04-07 11:30:00       61664.0  397.0   3330.0  1521.0    45758.0
# 229063  2018-07-14 01:45:00           NaN    NaN      NaN     NaN        NaN
# 59679   2013-09-13 15:45:00           NaN    NaN      NaN     NaN        NaN
# 189117  2017-05-23 23:15:00           NaN    NaN      NaN     NaN        NaN
# 74278   2014-02-12 17:30:00       70502.0  308.0   1006.0  3327.0    56777.0
# 216825  2018-03-08 14:15:00           NaN    NaN      NaN     NaN        NaN
# 93005   2014-08-26 19:15:00           NaN    NaN      NaN     NaN        NaN
# 94023   2014-09-06 09:45:00           NaN    NaN      NaN     NaN        NaN
# 50293   2013-06-07 21:15:00           NaN    NaN      NaN     NaN        NaN
# 27958   2012-10-18 05:30:00       44095.0  389.0   2089.0   830.0    40486.0
# 192304  2017-06-26 04:00:00       35820.0  145.0    248.0  1549.0    36294.0
# 182346  2017-03-14 10:30:00       63490.0  988.0     13.0  6527.0    45802.0
# 227421  2018-06-26 23:15:00           NaN    NaN      NaN     NaN        NaN
# 210545  2018-01-02 04:15:00           NaN    NaN      NaN     NaN        NaN
# 90177   2014-07-28 08:15:00           NaN    NaN      NaN     NaN        NaN
# 224815  2018-05-30 19:45:00           NaN    NaN      NaN     NaN        NaN
# 232357  2018-08-17 09:15:00           NaN    NaN      NaN     NaN        NaN
#
#         Eolien  Solaire  Hydraulique  Pompage  Bioénergies  Ech. physiques
# 18261      NaN      NaN          NaN      NaN          NaN             NaN
# 39851      NaN      NaN          NaN      NaN          NaN             NaN
# 60345      NaN      NaN          NaN      NaN          NaN             NaN
# 44398    976.0   1700.0       8062.0    -33.0        576.0          -623.0
# 229063     NaN      NaN          NaN      NaN          NaN             NaN
# 59679      NaN      NaN          NaN      NaN          NaN             NaN
# 189117     NaN      NaN          NaN      NaN          NaN             NaN
# 74278   5786.0    143.0      10243.0    -29.0        932.0         -7991.0
# 216825     NaN      NaN          NaN      NaN          NaN             NaN
# 93005      NaN      NaN          NaN      NaN          NaN             NaN
# 94023      NaN      NaN          NaN      NaN          NaN             NaN
# 50293      NaN      NaN          NaN      NaN          NaN             NaN
# 27958   3447.0      0.0       4630.0  -2336.0        620.0         -6060.0
# 192304   928.0     -1.0       3835.0  -2489.0       1121.0         -5810.0
# 182346   862.0   2925.0       9010.0     -4.0       1019.0         -3653.0
# 227421     NaN      NaN          NaN      NaN          NaN             NaN
# 210545     NaN      NaN          NaN      NaN          NaN             NaN
# 90177      NaN      NaN          NaN      NaN          NaN             NaN
# 224815     NaN      NaN          NaN      NaN          NaN             NaN
# 232357     NaN      NaN          NaN      NaN          NaN             NaN

# %% [markdown]
# ## Visualize Data

# %% [markdown]
# ### <font color='purple'> Quelle est la répartition des passagers par classe ? </font>
# -> Single categorical variable (une seule variable qualitative nominale)

# %% [markdown]
# ### <font color='purple'> Quelle est la répartition des passagers par sexe ? </font>
# -> type of variable(s)?

# %% [markdown]
# ### <font color='purple'>Distribution des passagers selon âge et sexe </font>
# -> type of variable(s)?

# %% [markdown]
# ### <font color='purple'>Quel est le taux de survie selon le sexe ? l’âge ? la classe ? </font>
# -> type of variable(s)?

# %% [markdown]
# ### <font color='purple'> Y a-t-il un lien entre prix payé pour le billet et l’âge des passagers ? </font>
# -> type of variable(s)?

# %% [markdown]
# # Energy Dataset

# %% [markdown]
# ## Import data

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Fare', data=df_titanic )
plt.title('Relation entre l\'âge et le prix payé pour le billet')
plt.xlabel('Âge des passagers')
plt.ylabel('Prix payé pour le billet')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Age', y='Fare', data=df_titanic, scatter_kws={'s':10})
plt.title('Régression linéaire entre l\'âge et le prix payé pour le billet')
plt.xlabel('Âge des passagers')
plt.ylabel('Prix payé pour le billet')
plt.show()

# %% [markdown]
# ## Visualize Data

# %% [markdown]
# ### <font color='purple'> Quels sont les types de variables ? Décrivez-les à l'aide d'un graphique. </font>

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(df['variable '], df['Fare'], gridsize=30, cmap='Blues')
plt.colorbar(label='Nombre de passagers')
plt.title('Densité des passagers par âge et prix du billet')
plt.xlabel('Âge des passagers')
plt.ylabel('Prix payé pour le billet')
plt.show()

# %% [markdown]
# ### <font color='purple'> Quelle est l'évolution de la consommation ? </font>

# %% [markdown]
# ### <font color='purple'> Quand a-t-on a un excédant / un déficit de production ? </font>

# %% [markdown]
# ### <font color='purple'> Y a-t-il une corrélation entre les différents types de production ? </font>
